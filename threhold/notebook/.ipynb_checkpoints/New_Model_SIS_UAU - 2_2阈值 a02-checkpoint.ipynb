# %%
# import networkx as nx
import numpy as np
import scipy.io as scio
import matplotlib.pyplot as plt
import seaborn as sns
import random
import time

# %matplotlib inline
plt.style.use('ggplot')
sns.set()

# %%
# 对称检查函数
def check_symmetric(a, tol=1e-8):
    return np.allclose(a, a.T, atol=tol)

# %%
# 网络数据导入为numpy数组
dataFile_1 = '../data/WS_2000_4_03.mat'
data_1 = scio.loadmat(dataFile_1)
network_scale_1 = data_1['A'].shape
network_physical = np.array(data_1['A'])
# network_physical = nx.Graph(data['A'])

dataFile_2 = '../data/WS_2000_4_03_add_400_edges.mat'
data_2 = scio.loadmat(dataFile_2)
network_scale_2  = data_2['B'].shape
network_information = np.array(data_2['B'])
# network_information = nx.Graph(data['A'])

# 数据检查
assert network_scale_1 == network_scale_2, "networks\' size don\'t match!"
assert check_symmetric(network_physical), "network_physical doesn\'t symmetry!"
assert check_symmetric(network_information), "network_information doesn\'t symmetry!"
if np.sum(np.sum(network_physical, axis=0)==0):
    print("The network is integral")

# %%
# 参数设置

random.seed(256)
np.random.seed(256)    #指定生成“特定”的随机数

# 5. 阈值信息
batas = [0.10, 0.12, 0.14, 0.16, 0.18, 0.20, \
         0.22, 0.24, 0.26, 0.28, 0.30, 0.32, 0.34, 0.36, 0.38, 0.40, \
         0.42, 0.44, 0.46, 0.48, 0.50, 0.52, 0.54, 0.56, 0.58, 0.60, \
         0.62, 0.64, 0.66, 0.68, 0.70, 0.72, 0.74, 0.76, 0.78, 0.80，\
         0.82, 0.84, 0.86, 0.88, 0.90, 0.92, 0.94, 0.96, 0.98, 1.0]
i_beta_22_02 = np.zeros([len(batas)])

# %%
time_start_outter = time.time()

for b in range(len(batas)):
    bata = batas[b]
    
    # 0. 公共参数
    Monte_Carlo_loop = 50    # 蒙特卡洛模拟次数
    time_steps = 100    # 总时间步数
    N = network_scale_1[0]    # 网络节点数

    # 1. SIS参数
    # bata = 0.2    # 感染概率
    mu = 0.4    # 恢复概率

    Nodes_SIS = np.zeros([Monte_Carlo_loop, time_steps, N])    # N行代表时间步数，T列代表节点数，记录每步所有节点的感染状态

    infective_count = np.zeros([Monte_Carlo_loop, time_steps])    # 每步感染节点数,用于最终统计
    infective_count_average = np.zeros([1, time_steps])

    # 2. UAU参数
    lamda = 0.3    # 传播率
    delta = 0.6    # 遗忘率

    Nodes_UAU = np.zeros([Monte_Carlo_loop, time_steps, N])    # 存储网络中每个节点的知情状态快照

    awareness_count = np.zeros([Monte_Carlo_loop, time_steps])    # 每步知晓节点数量,用于最终统计
    awareness_count_average = np.zeros([1, time_steps])

    # 3. 节点警觉状态
    alert = 0.2
    inalert = 1 - alert

    Node_alert = np.zeros([Monte_Carlo_loop, time_steps, N])    # 存储网络中每个节点的活跃状态快照
    alert_count = np.zeros([Monte_Carlo_loop, time_steps])    # 每步知晓节点数量,用于最终统计
    alert_count_average = np.zeros([1, time_steps])

    # 4. 其他参数
    aplha = 0.4    # 信息上传率
    sigma_S = 0.5    # S节点在知道信息后的防御系数/感染率衰减, 相当于减少与周围人的接触
    
    
    time_start_inner = time.time()
    for loop in range(Monte_Carlo_loop):

        # 是否必要选择一定比例节点用于初始化
        p = random.randint(0, N-1)    # 初始始随机选出一个感染节点，四舍五入
        Nodes_SIS[loop, 0, p] = 1    # 第一步标出初始感染节点的位置
        Nodes_UAU[loop, 0, p] = 1    # 随机初始化一个节点使其处于感染状态，当前可感染状态节点的快照

        # 初始节点依概率变得警觉
        p0 = np.random.rand(1)
        if p0 < alert:
            Node_alert[loop, 0, p] = 1    # 初始节点变得警觉


        # ----------开始时间步数模拟----------
        for t in range(time_steps-1):

            # ----------UAU演化----------
            for i in range(N):

                # 如果节点i是未知节点
                if Nodes_UAU[loop, t, i] == 0:
                    neighbor_total = np.where((network_information[i, :] == 1))[0]    # 查找其邻居
                    awareness_nodes = np.where((Nodes_UAU[loop, t, :] == 1))[0]    # 查找传播节点
                    neighbor_listener = np.intersect1d(awareness_nodes, neighbor_total)    # 取交集，真正可以传播它的邻居
                    Num_neighbor_listener = len(neighbor_listener)    # 统计数量

                    # -----UAU传播过程-----
                    aware_rate = lamda
                    aware_temp = (1 - aware_rate) ** Num_neighbor_listener    # 最终计算的传播率
                    a1 = 1 - aware_temp

                    p = np.random.rand(1)
                    # 传播成功
                    if p <= a1:
                        Nodes_UAU[loop, t+1, i] = 1

                        # 已知的节点如果是非警觉的，节点依概率变得警觉
                        if Node_alert[loop, t, i] == 0:
                            p = np.random.rand(1)
                            if p < alert:
                                Node_alert[loop, t+1, i] = 1
                            else:
                                Node_alert[loop, t+1, i] = 0
                        # 已知的节点如果是警觉的，保持警觉
                        elif Node_alert[loop, t, i] == 1:
                            Node_alert[loop, t+1, i] = 1
                        else:
                            print("There is an accidence in A1!")

                    # 传播失败
                    else:
                        Nodes_UAU[loop, t+1, i] = 0

                        # 继续保持U的节点如果是警觉的，节点依概率变得非警觉
                        if Node_alert[loop, t, i] == 1:
                            p = np.random.rand(1)
                            if p < inalert:
                                Node_alert[loop, t+1, i] = 0
                            else:
                                Node_alert[loop, t+1, i] = 1
                        # 已知的节点如果是非警觉的，保持非警觉
                        elif Node_alert[loop, t, i] == 0:
                            Node_alert[loop, t+1, i] = 0
                        else:
                            print("There is an accidence in A2!")


                # -----UAU遗忘过程-----
                elif Nodes_UAU[loop, t, i] == 1:

                    p = np.random.rand(1)
                    # 遗忘成功
                    if p <= delta:
                        Nodes_UAU[loop, t+1, i] = 0    # 这个节点遗忘

                        # 遗忘的节点如果是警觉的，节点依概率变得非警觉
                        if Node_alert[loop, t, i] == 1:
                            p = np.random.rand(1)
                            if p < inalert:
                                Node_alert[loop, t+1, i] = 0
                            else:
                                Node_alert[loop, t+1, i] = 1
                        # 遗忘的节点如果是非警觉的，保持非警觉
                        elif Node_alert[loop, t, i] == 0:
                            Node_alert[loop, t+1, i] = 0
                        else:
                            print("There is an accidence in A3!")

                    # 遗忘失败
                    else:
                        Nodes_UAU[loop, t+1, i] = 1    # 遗忘失败，下个时刻节点保持知觉

                        # 遗忘失败且非警觉，依旧有概率变为警觉
                        if Node_alert[loop, t, i] == 0:
                            p = np.random.rand(1)
                            if p < alert:
                                Node_alert[loop, t+1, i] = 1
                            else:
                                Node_alert[loop, t+1, i] = 0
                        # 遗忘失败且已经警觉，警觉性保持不变（只有A->U才会变化） 
                        elif Node_alert[loop, t, i] == 1:
                            Node_alert[loop, t+1, i] = 1
                        else:
                            print("There is an accidence in A4!")   


            # ----------SIS演化----------
            for i in range(N):

                # 0代表易感(S)，如果节点i健康且非警觉，就查找其I状态的邻居（非警觉节点处理方式不变-与所有结节点触）
                if ((Nodes_SIS[loop, t, i] == 0) and (Node_alert[loop, t, i] == 0)):

                    neighbor_total = np.where((network_physical[i, :] == 1))[0]    # 查找其邻居
                    infective_nodes = np.where((Nodes_SIS[loop, t, :] == 1))[0]    # 查找感染节点
                    neighbor_infective = np.intersect1d(infective_nodes, neighbor_total)    # 取交集，真正可以感染它的邻居
                    Num_neighbor_infective = len(neighbor_infective)    # 统计数量

                    infect_rate_current = bata    # 当前临时感染率
                    rate_temp = 1    # 用于计算感染率

                    # SIS感染率改变规则
                    # 非知觉节点
                    if Nodes_UAU[loop, t, i] == 0:
                        rate_temp = (1 - infect_rate_current) ** Num_neighbor_infective                 
                    # 知觉节点
                    elif Nodes_UAU[loop, t, i] == 1:
                        infect_rate_current = infect_rate_current * sigma_S    # 当前临时感染率
                        rate_temp = (1 - infect_rate_current) ** Num_neighbor_infective


                    # -----SIS感染过程1-----
                    v1 = 1 - rate_temp    # 最终计算的感染率
                    p = np.random.rand(1)
                    if p <= v1:
                        Nodes_SIS[loop, t+1, i] = 1

                        # 感染节点信息上传(知晓)
                        p = np.random.rand(1)
                        if  p <= aplha:
                            Nodes_UAU[loop, t+1, i] = 1

                            # 成功感染的节点下一时刻依概率变得警觉
                            p = np.random.rand(1)
                            if p < alert:
                                Node_alert[loop, t+1, i] = 1    # 这个节点变得警觉
                            else:
                                Node_alert[loop, t+1, i] = 0
                        else:
                            Nodes_UAU[loop, t+1, i] = 0
                    else:
                        Nodes_SIS[loop, t+1, i] = 0

                # 0代表易感(S)，如果节点i健康且警觉，就查找其I状态的警觉邻居
                elif ((Nodes_SIS[loop, t, i] == 0) and (Node_alert[loop, t, i] == 1)):

                    neighbor_total = np.where((network_physical[i, :] == 1))[0]    # 查找其邻居
                    infective_nodes = np.where((Nodes_SIS[loop, t, :] == 1))[0]    # 感染节点
                    alert_nodes = np.where((Node_alert[loop, t, :] == 0))[0]    # 警觉节点

                    neighbor_infective = np.intersect1d(infective_nodes, neighbor_total)    # 取交集，真正可以感染它的邻居
                    neighbor_infective_alert = np.intersect1d(neighbor_infective, alert_nodes)    # 取交集，真正可以感染它的警觉邻居

                    Num_neighbor_infective_alert = len(neighbor_infective_alert)    # 统计

                    infect_rate_current = bata    # 当前临时感染率
                    rate_temp = 1    # 用于计算感染率

                    # SIS感染率改变规则
                    # 非知觉节点
                    if Nodes_UAU[loop, t, i] == 0:
                        rate_temp = (1 - infect_rate_current) ** Num_neighbor_infective_alert                 
                    # 知觉节点
                    elif Nodes_UAU[loop, t, i] == 1:
                        infect_rate_current = infect_rate_current * sigma_S    # 当前临时感染率
                        rate_temp = (1 - infect_rate_current) ** Num_neighbor_infective_alert


                    # -----SIS感染过程2-----
                    v1 = 1 - rate_temp    # 最终计算的感染率
                    p = np.random.rand(1)
                    if p <= v1:
                        Nodes_SIS[loop, t+1, i] = 1

                        # 感染节点信息上传(知晓)
                        p = np.random.rand(1)
                        if  p <= aplha:
                            Nodes_UAU[loop, t+1, i] = 1
                        else:
                            Nodes_UAU[loop, t+1, i] = 0
                    else:
                        Nodes_SIS[loop, t+1, i] = 0

                    # S节点已经是警觉节点，被感染后继续保持警觉
                    Node_alert[loop, t+1, i] = 1    # 这个节点变得警觉

                # -----SIS康复过程-----
                elif Nodes_SIS[loop, t, i] == 1:

                    recover_rate_current = mu
                    p = np.random.rand(1) 
                    if p <= recover_rate_current:
                        Nodes_SIS[loop, t+1, i] = 0
                    else:
                        Nodes_SIS[loop, t+1, i] = 1

                else:
                    print("There is an else condition in SIS!")
            
        print("    loop_MC {} - time has passed: {} ".format(loop, time.time()-time_start_inner))

    # 处理数据
    for loop_ in range(Monte_Carlo_loop):
        infective_count[loop_,:] = np.sum(Nodes_SIS[loop_,:,:], axis=1)
#         awareness_count[loop_,:] = np.sum(Nodes_UAU[loop_,:,:], axis=1)
#         alert_count[loop_,:] = np.sum(Node_alert[loop_,:,:], axis=1)

    infective_count_average = np.mean(infective_count, axis=0)
#     awareness_count_average = np.mean(awareness_count, axis=0)
#     alert_count_average = np.mean(alert_count, axis=0)

    assert infective_count_average.shape == (time_steps,), "infective_count_average\'s size don\'t match!"
#     assert awareness_count_average.shape == (time_steps,), "awareness_count_average\'s size don\'t match!"
#     assert alert_count_average.shape == (time_steps,), "alert_count_average\'s size don\'t match!"
    
    i_beta = infective_count_average/N
    i_beta_22_02[b] = i_beta[99]
    
    print("loop_b {} - time has passed: {} ".format(b, time.time()-time_start_outter))
# Out:
#     loop_MC 0 - time has passed: 43.65611410140991
#     loop_MC 1 - time has passed: 77.82736086845398
#     loop_MC 2 - time has passed: 120.82749581336975
#     loop_MC 3 - time has passed: 160.15456771850586
#     loop_MC 4 - time has passed: 199.33962225914001
#     loop_MC 5 - time has passed: 241.24008440971375
#     loop_MC 6 - time has passed: 282.10051918029785
#     loop_MC 7 - time has passed: 322.3548276424408
#     loop_MC 8 - time has passed: 360.1337993144989
#     loop_MC 9 - time has passed: 398.4264645576477
#     loop_MC 10 - time has passed: 439.22816944122314
#     loop_MC 11 - time has passed: 477.484769821167
#     loop_MC 12 - time has passed: 515.3854322433472
#     loop_MC 13 - time has passed: 554.7461879253387
#     loop_MC 14 - time has passed: 592.727689743042
#     loop_MC 15 - time has passed: 633.5292356014252
#     loop_MC 16 - time has passed: 667.1715059280396
#     loop_MC 17 - time has passed: 706.952348947525
#     loop_MC 18 - time has passed: 747.1803348064423
#     loop_MC 19 - time has passed: 784.6909561157227
#     loop_MC 20 - time has passed: 824.0905001163483
#     loop_MC 21 - time has passed: 859.8447222709656
#     loop_MC 22 - time has passed: 898.4111657142639
#     loop_MC 23 - time has passed: 934.2040417194366
#     loop_MC 24 - time has passed: 970.5507054328918
#     loop_MC 25 - time has passed: 1013.9904663562775
#     loop_MC 26 - time has passed: 1052.6130270957947
#     loop_MC 27 - time has passed: 1089.2511341571808
#     loop_MC 28 - time has passed: 1127.1706745624542
#     loop_MC 29 - time has passed: 1166.9076476097107
# loop_b 0 - time has passed: 1166.9232695102692
#     loop_MC 0 - time has passed: 29.95749044418335
#     loop_MC 1 - time has passed: 68.62363624572754
#     loop_MC 2 - time has passed: 105.05429792404175
#     loop_MC 3 - time has passed: 144.8511130809784
#     loop_MC 4 - time has passed: 183.16535425186157
#     loop_MC 5 - time has passed: 222.65485620498657
#     loop_MC 6 - time has passed: 253.3787670135498
#     loop_MC 7 - time has passed: 291.0279369354248
#     loop_MC 8 - time has passed: 331.5459132194519
#     loop_MC 9 - time has passed: 371.6698923110962
#     loop_MC 10 - time has passed: 412.03309082984924
#     loop_MC 11 - time has passed: 451.83367562294006
#     loop_MC 12 - time has passed: 492.43431878089905
#     loop_MC 13 - time has passed: 534.63920545578
#     loop_MC 14 - time has passed: 563.8823232650757
#     loop_MC 15 - time has passed: 602.0204422473907
#     loop_MC 16 - time has passed: 638.9848575592041
#     loop_MC 17 - time has passed: 670.8164584636688
#     loop_MC 18 - time has passed: 701.2890548706055
#     loop_MC 19 - time has passed: 739.0641529560089
#     loop_MC 20 - time has passed: 777.8510434627533
#     loop_MC 21 - time has passed: 815.6881811618805
#     loop_MC 22 - time has passed: 851.4337577819824
#     loop_MC 23 - time has passed: 880.6389276981354
#     loop_MC 24 - time has passed: 910.646966457367
#     loop_MC 25 - time has passed: 947.3981375694275
#     loop_MC 26 - time has passed: 986.3276896476746
#     loop_MC 27 - time has passed: 1024.1897087097168
#     loop_MC 28 - time has passed: 1063.854653120041
#     loop_MC 29 - time has passed: 1094.1258430480957
# loop_b 1 - time has passed: 2261.0803561210632
#     loop_MC 0 - time has passed: 36.33018970489502
#     loop_MC 1 - time has passed: 76.0819001197815
#     loop_MC 2 - time has passed: 113.42939448356628
#     loop_MC 3 - time has passed: 142.58810353279114
#     loop_MC 4 - time has passed: 181.7387924194336
#     loop_MC 5 - time has passed: 221.11512851715088
#     loop_MC 6 - time has passed: 262.0892267227173
#     loop_MC 7 - time has passed: 300.38311648368835
#     loop_MC 8 - time has passed: 336.3429579734802
#     loop_MC 9 - time has passed: 364.88543248176575
#     loop_MC 10 - time has passed: 400.05232548713684
#     loop_MC 11 - time has passed: 437.1923987865448
#     loop_MC 12 - time has passed: 472.6847493648529
#     loop_MC 13 - time has passed: 502.25502586364746
#     loop_MC 14 - time has passed: 539.924387216568
#     loop_MC 15 - time has passed: 577.5024924278259
#     loop_MC 16 - time has passed: 610.2769114971161
#     loop_MC 17 - time has passed: 652.4503884315491
#     loop_MC 18 - time has passed: 684.6320462226868
#     loop_MC 19 - time has passed: 721.7872362136841
#     loop_MC 20 - time has passed: 758.7462828159332
#     loop_MC 21 - time has passed: 795.5246632099152
#     loop_MC 22 - time has passed: 824.5478937625885
#     loop_MC 23 - time has passed: 853.3566000461578
#     loop_MC 24 - time has passed: 891.606367111206
#     loop_MC 25 - time has passed: 928.9003851413727
#     loop_MC 26 - time has passed: 966.4367859363556
#     loop_MC 27 - time has passed: 1003.4983260631561
#     loop_MC 28 - time has passed: 1040.110027551651
#     loop_MC 29 - time has passed: 1069.6373908519745
# loop_b 2 - time has passed: 3330.748990058899
#     loop_MC 0 - time has passed: 35.896737575531006
#     loop_MC 1 - time has passed: 73.16316795349121
#     loop_MC 2 - time has passed: 111.58113694190979
#     loop_MC 3 - time has passed: 147.9149420261383
#     loop_MC 4 - time has passed: 185.80910921096802
#     loop_MC 5 - time has passed: 226.51995491981506
#     loop_MC 6 - time has passed: 264.2669770717621
#     loop_MC 7 - time has passed: 300.9998970031738
#     loop_MC 8 - time has passed: 339.20037722587585
#     loop_MC 9 - time has passed: 368.3213493824005
#     loop_MC 10 - time has passed: 405.7121729850769
#     loop_MC 11 - time has passed: 443.63992619514465
#     loop_MC 12 - time has passed: 481.3660545349121
#     loop_MC 13 - time has passed: 518.1568286418915
#     loop_MC 14 - time has passed: 555.4141702651978
#     loop_MC 15 - time has passed: 585.5979809761047
#     loop_MC 16 - time has passed: 621.4378395080566
#     loop_MC 17 - time has passed: 658.7409150600433
#     loop_MC 18 - time has passed: 694.5017461776733
#     loop_MC 19 - time has passed: 732.1792974472046
#     loop_MC 20 - time has passed: 769.5283124446869
#     loop_MC 21 - time has passed: 804.8067357540131
#     loop_MC 22 - time has passed: 843.600622177124
#     loop_MC 23 - time has passed: 879.8576719760895
#     loop_MC 24 - time has passed: 918.1302073001862
#     loop_MC 25 - time has passed: 956.211932182312
#     loop_MC 26 - time has passed: 993.475753068924
#     loop_MC 27 - time has passed: 1022.6012091636658
#     loop_MC 28 - time has passed: 1052.2105243206024
#     loop_MC 29 - time has passed: 1089.677353143692
# loop_b 3 - time has passed: 4420.474542140961
#     loop_MC 0 - time has passed: 36.305542945861816
#     loop_MC 1 - time has passed: 72.25480270385742
#     loop_MC 2 - time has passed: 108.03096985816956
#     loop_MC 3 - time has passed: 144.7733769416809
#     loop_MC 4 - time has passed: 182.61985874176025
#     loop_MC 5 - time has passed: 221.04991173744202
#     loop_MC 6 - time has passed: 256.7481756210327
#     loop_MC 7 - time has passed: 292.95620918273926
#     loop_MC 8 - time has passed: 328.859162569046
#     loop_MC 9 - time has passed: 365.4914753437042
#     loop_MC 10 - time has passed: 401.46781182289124
#     loop_MC 11 - time has passed: 436.54072308540344
#     loop_MC 12 - time has passed: 472.8895888328552
#     loop_MC 13 - time has passed: 509.43689346313477
#     loop_MC 14 - time has passed: 546.3029761314392
#     loop_MC 15 - time has passed: 583.7239468097687
#     loop_MC 16 - time has passed: 622.6827809810638
#     loop_MC 17 - time has passed: 659.1190621852875
#     loop_MC 18 - time has passed: 694.4593827724457
#     loop_MC 19 - time has passed: 730.9269635677338
#     loop_MC 20 - time has passed: 767.8008987903595
#     loop_MC 21 - time has passed: 803.0736875534058
#     loop_MC 22 - time has passed: 838.3939116001129
#     loop_MC 23 - time has passed: 874.7904920578003
#     loop_MC 24 - time has passed: 911.0988879203796
#     loop_MC 25 - time has passed: 947.6366198062897
#     loop_MC 26 - time has passed: 984.3189249038696
#     loop_MC 27 - time has passed: 1012.9380476474762
#     loop_MC 28 - time has passed: 1050.9886393547058
#     loop_MC 29 - time has passed: 1087.114514350891
# loop_b 4 - time has passed: 5507.623628377914
#     loop_MC 0 - time has passed: 28.801046133041382
#     loop_MC 1 - time has passed: 64.2687418460846
#     loop_MC 2 - time has passed: 101.84333562850952
#     loop_MC 3 - time has passed: 140.22668981552124
#     loop_MC 4 - time has passed: 170.6994664669037
#     loop_MC 5 - time has passed: 207.9162151813507
#     loop_MC 6 - time has passed: 243.89134788513184
#     loop_MC 7 - time has passed: 281.1372356414795
#     loop_MC 8 - time has passed: 317.6920847892761
#     loop_MC 9 - time has passed: 355.0664048194885
#     loop_MC 10 - time has passed: 383.6549608707428
#     loop_MC 11 - time has passed: 412.1063630580902
#     loop_MC 12 - time has passed: 450.07147550582886
#     loop_MC 13 - time has passed: 485.83217787742615
#     loop_MC 14 - time has passed: 522.1910862922668
#     loop_MC 15 - time has passed: 559.686859369278
#     loop_MC 16 - time has passed: 596.5081779956818
#     loop_MC 17 - time has passed: 633.5238864421844
#     loop_MC 18 - time has passed: 662.9919333457947
#     loop_MC 19 - time has passed: 692.1793627738953
#     loop_MC 20 - time has passed: 729.1887664794922
#     loop_MC 21 - time has passed: 765.9002463817596
#     loop_MC 22 - time has passed: 802.9241631031036
#     loop_MC 23 - time has passed: 840.5306248664856
#     loop_MC 24 - time has passed: 877.9949924945831
#     loop_MC 25 - time has passed: 916.0432543754578
#     loop_MC 26 - time has passed: 953.2915751934052
#     loop_MC 27 - time has passed: 989.6030974388123
#     loop_MC 28 - time has passed: 1027.5444252490997
#     loop_MC 29 - time has passed: 1056.5722029209137
# loop_b 5 - time has passed: 6564.242696762085
#     loop_MC 0 - time has passed: 36.7589430809021
#     loop_MC 1 - time has passed: 74.27354598045349
#     loop_MC 2 - time has passed: 115.72040343284607
#     loop_MC 3 - time has passed: 152.90709376335144
#     loop_MC 4 - time has passed: 188.60874795913696
#     loop_MC 5 - time has passed: 226.29930329322815
#     loop_MC 6 - time has passed: 264.72402715682983
#     loop_MC 7 - time has passed: 303.02191972732544
#     loop_MC 8 - time has passed: 339.5937113761902
#     loop_MC 9 - time has passed: 377.0203995704651
#     loop_MC 10 - time has passed: 413.2060887813568
#     loop_MC 11 - time has passed: 451.70442509651184
#     loop_MC 12 - time has passed: 491.8361175060272
#     loop_MC 13 - time has passed: 530.9118974208832
#     loop_MC 14 - time has passed: 572.204615354538
#     loop_MC 15 - time has passed: 620.2240250110626
#     loop_MC 16 - time has passed: 662.5442173480988
#     loop_MC 17 - time has passed: 700.1244513988495
#     loop_MC 18 - time has passed: 737.092657327652
#     loop_MC 19 - time has passed: 773.655029296875
#     loop_MC 20 - time has passed: 809.1893818378448
#     loop_MC 21 - time has passed: 845.314380645752
#     loop_MC 22 - time has passed: 874.7094039916992
#     loop_MC 23 - time has passed: 913.3018450737
#     loop_MC 24 - time has passed: 949.4086346626282
#     loop_MC 25 - time has passed: 986.8288021087646
#     loop_MC 26 - time has passed: 1023.3370819091797
#     loop_MC 27 - time has passed: 1053.3730273246765
#     loop_MC 28 - time has passed: 1091.0958397388458
#     loop_MC 29 - time has passed: 1128.029449224472
# loop_b 6 - time has passed: 7692.319012880325
#     loop_MC 0 - time has passed: 37.99737906455994
#     loop_MC 1 - time has passed: 76.02769374847412
#     loop_MC 2 - time has passed: 113.23162603378296
#     loop_MC 3 - time has passed: 142.02474117279053
#     loop_MC 4 - time has passed: 179.5011990070343
#     loop_MC 5 - time has passed: 216.96560883522034
#     loop_MC 6 - time has passed: 253.57750606536865
#     loop_MC 7 - time has passed: 288.88120555877686
#     loop_MC 8 - time has passed: 326.1155927181244
#     loop_MC 9 - time has passed: 363.2195613384247
#     loop_MC 10 - time has passed: 402.158762216568
#     loop_MC 11 - time has passed: 439.26704931259155
#     loop_MC 12 - time has passed: 475.8712811470032
#     loop_MC 13 - time has passed: 514.0144588947296
#     loop_MC 14 - time has passed: 551.5414190292358
#     loop_MC 15 - time has passed: 588.6336355209351
#     loop_MC 16 - time has passed: 626.6414394378662
#     loop_MC 17 - time has passed: 664.5658597946167
#     loop_MC 18 - time has passed: 701.8046126365662
#     loop_MC 19 - time has passed: 740.429826259613
#     loop_MC 20 - time has passed: 778.662713766098
#     loop_MC 21 - time has passed: 816.441951751709
#     loop_MC 22 - time has passed: 852.8986990451813
#     loop_MC 23 - time has passed: 890.2590091228485
#     loop_MC 24 - time has passed: 927.5487041473389
#     loop_MC 25 - time has passed: 964.9651341438293
#     loop_MC 26 - time has passed: 1002.4033918380737
#     loop_MC 27 - time has passed: 1038.9925067424774
#     loop_MC 28 - time has passed: 1077.5181338787079
#     loop_MC 29 - time has passed: 1114.6100342273712
# loop_b 7 - time has passed: 8806.958634376526
#     loop_MC 0 - time has passed: 38.477850914001465
#     loop_MC 1 - time has passed: 74.49884629249573
#     loop_MC 2 - time has passed: 111.93534088134766
#     loop_MC 3 - time has passed: 148.67645120620728
#     loop_MC 4 - time has passed: 186.5927550792694
#     loop_MC 5 - time has passed: 223.50781297683716
#     loop_MC 6 - time has passed: 251.40687704086304
#     loop_MC 7 - time has passed: 289.0864245891571
#     loop_MC 8 - time has passed: 326.0288317203522
#     loop_MC 9 - time has passed: 363.5785279273987
#     loop_MC 10 - time has passed: 400.1201171875
#     loop_MC 11 - time has passed: 436.9532356262207
#     loop_MC 12 - time has passed: 475.7414901256561
#     loop_MC 13 - time has passed: 512.632018327713
#     loop_MC 14 - time has passed: 548.7844638824463
#     loop_MC 15 - time has passed: 586.0728185176849
#     loop_MC 16 - time has passed: 621.8467741012573
#     loop_MC 17 - time has passed: 659.1192591190338
#     loop_MC 18 - time has passed: 696.9004209041595
#     loop_MC 19 - time has passed: 734.1079256534576
#     loop_MC 20 - time has passed: 771.4004864692688
#     loop_MC 21 - time has passed: 808.1963381767273
#     loop_MC 22 - time has passed: 844.5111372470856
#     loop_MC 23 - time has passed: 881.8528242111206
#     loop_MC 24 - time has passed: 918.4500381946564
#     loop_MC 25 - time has passed: 956.1872799396515
#     loop_MC 26 - time has passed: 993.052726984024
#     loop_MC 27 - time has passed: 1029.9647209644318
#     loop_MC 28 - time has passed: 1066.8652703762054
#     loop_MC 29 - time has passed: 1109.3034007549286
# loop_b 8 - time has passed: 9916.29361319542
#     loop_MC 0 - time has passed: 35.64023971557617
#     loop_MC 1 - time has passed: 73.0869836807251
#     loop_MC 2 - time has passed: 109.47374367713928
#     loop_MC 3 - time has passed: 146.11006951332092
#     loop_MC 4 - time has passed: 181.44853520393372
#     loop_MC 5 - time has passed: 218.1750030517578
#     loop_MC 6 - time has passed: 255.90093421936035
#     loop_MC 7 - time has passed: 291.0711770057678
#     loop_MC 8 - time has passed: 328.0572409629822
#     loop_MC 9 - time has passed: 364.6579568386078
#     loop_MC 10 - time has passed: 400.9541668891907
#     loop_MC 11 - time has passed: 440.83494234085083
#     loop_MC 12 - time has passed: 478.2718813419342
#     loop_MC 13 - time has passed: 515.0274262428284
#     loop_MC 14 - time has passed: 552.7321615219116
#     loop_MC 15 - time has passed: 587.8953294754028
#     loop_MC 16 - time has passed: 624.676864862442
#     loop_MC 17 - time has passed: 659.5826594829559
#     loop_MC 18 - time has passed: 695.5068995952606
#     loop_MC 19 - time has passed: 731.7061748504639
#     loop_MC 20 - time has passed: 767.9724109172821
#     loop_MC 21 - time has passed: 803.4868643283844
#     loop_MC 22 - time has passed: 838.7684066295624
#     loop_MC 23 - time has passed: 875.7983076572418
#     loop_MC 24 - time has passed: 910.736809015274
#     loop_MC 25 - time has passed: 949.5835404396057
#     loop_MC 26 - time has passed: 986.65873503685
#     loop_MC 27 - time has passed: 1023.1100385189056
#     loop_MC 28 - time has passed: 1059.684591293335
#     loop_MC 29 - time has passed: 1095.7883884906769
# loop_b 9 - time has passed: 11012.113248825073
#     loop_MC 0 - time has passed: 35.7534077167511
#     loop_MC 1 - time has passed: 70.75339484214783
#     loop_MC 2 - time has passed: 105.13810157775879
#     loop_MC 3 - time has passed: 140.88306593894958
#     loop_MC 4 - time has passed: 176.81545162200928
#     loop_MC 5 - time has passed: 212.4245069026947
#     loop_MC 6 - time has passed: 247.67548871040344
#     loop_MC 7 - time has passed: 284.4025208950043
#     loop_MC 8 - time has passed: 318.88064980506897
#     loop_MC 9 - time has passed: 353.01525020599365
#     loop_MC 10 - time has passed: 387.4707453250885
#     loop_MC 11 - time has passed: 423.67825269699097
#     loop_MC 12 - time has passed: 457.5866138935089
#     loop_MC 13 - time has passed: 493.22334599494934
#     loop_MC 14 - time has passed: 524.0530648231506
#     loop_MC 15 - time has passed: 559.1945955753326
#     loop_MC 16 - time has passed: 594.8214688301086
#     loop_MC 17 - time has passed: 632.684641122818
#     loop_MC 18 - time has passed: 666.9708771705627
#     loop_MC 19 - time has passed: 701.3964757919312
#     loop_MC 20 - time has passed: 736.040491104126
#     loop_MC 21 - time has passed: 772.0027861595154
#     loop_MC 22 - time has passed: 807.0803186893463
#     loop_MC 23 - time has passed: 835.4889454841614
#     loop_MC 24 - time has passed: 870.4239280223846
#     loop_MC 25 - time has passed: 906.6928946971893
#     loop_MC 26 - time has passed: 940.0900766849518
#     loop_MC 27 - time has passed: 978.0557556152344
#     loop_MC 28 - time has passed: 1015.7074718475342
#     loop_MC 29 - time has passed: 1050.3099331855774
# loop_b 10 - time has passed: 12062.45442700386
#     loop_MC 0 - time has passed: 33.388062715530396
#     loop_MC 1 - time has passed: 69.55246496200562
#     loop_MC 2 - time has passed: 103.4286859035492
#     loop_MC 3 - time has passed: 139.9183485507965
#     loop_MC 4 - time has passed: 173.82621908187866
#     loop_MC 5 - time has passed: 207.30475306510925
#     loop_MC 6 - time has passed: 243.28313899040222
#     loop_MC 7 - time has passed: 276.2178153991699
#     loop_MC 8 - time has passed: 309.5532913208008
#     loop_MC 9 - time has passed: 344.10998463630676
#     loop_MC 10 - time has passed: 378.8090934753418
#     loop_MC 11 - time has passed: 411.1273834705353
#     loop_MC 12 - time has passed: 448.9267256259918
#     loop_MC 13 - time has passed: 481.8732032775879
#     loop_MC 14 - time has passed: 515.7487714290619
#     loop_MC 15 - time has passed: 548.3809475898743
#     loop_MC 16 - time has passed: 581.7983841896057
#     loop_MC 17 - time has passed: 616.1870217323303
#     loop_MC 18 - time has passed: 648.7155523300171
#     loop_MC 19 - time has passed: 682.0520639419556
#     loop_MC 20 - time has passed: 711.430281162262
#     loop_MC 21 - time has passed: 744.8019649982452
#     loop_MC 22 - time has passed: 781.2420656681061
#     loop_MC 23 - time has passed: 816.141813993454
#     loop_MC 24 - time has passed: 849.9946141242981
#     loop_MC 25 - time has passed: 883.6835117340088
#     loop_MC 26 - time has passed: 918.207358121872
#     loop_MC 27 - time has passed: 954.5552208423615
#     loop_MC 28 - time has passed: 991.5253098011017
#     loop_MC 29 - time has passed: 1023.739709854126
# loop_b 11 - time has passed: 13086.20975780487
#     loop_MC 0 - time has passed: 33.917304277420044
#     loop_MC 1 - time has passed: 67.44376611709595
#     loop_MC 2 - time has passed: 98.85661149024963
#     loop_MC 3 - time has passed: 134.4426679611206
#     loop_MC 4 - time has passed: 170.52052569389343
#     loop_MC 5 - time has passed: 202.78960013389587
#     loop_MC 6 - time has passed: 234.79079866409302
#     loop_MC 7 - time has passed: 266.45836210250854
#     loop_MC 8 - time has passed: 298.82338070869446
#     loop_MC 9 - time has passed: 330.3098180294037
#     loop_MC 10 - time has passed: 362.4516251087189
#     loop_MC 11 - time has passed: 394.2794508934021
#     loop_MC 12 - time has passed: 432.1396429538727
#     loop_MC 13 - time has passed: 465.5045847892761
#     loop_MC 14 - time has passed: 496.10926485061646
#     loop_MC 15 - time has passed: 528.9479351043701
#     loop_MC 16 - time has passed: 566.0818996429443
#     loop_MC 17 - time has passed: 602.2437844276428
#     loop_MC 18 - time has passed: 636.7404661178589
#     loop_MC 19 - time has passed: 670.8667590618134
#     loop_MC 20 - time has passed: 706.7297859191895
#     loop_MC 21 - time has passed: 739.0988938808441
#     loop_MC 22 - time has passed: 771.846186876297
#     loop_MC 23 - time has passed: 803.5981559753418
#     loop_MC 24 - time has passed: 835.4603898525238
#     loop_MC 25 - time has passed: 867.9006862640381
#     loop_MC 26 - time has passed: 900.4237284660339
#     loop_MC 27 - time has passed: 934.4805400371552
#     loop_MC 28 - time has passed: 966.8200488090515
#     loop_MC 29 - time has passed: 999.75421833992
# loop_b 12 - time has passed: 14085.995555639267
#     loop_MC 0 - time has passed: 32.79451537132263
#     loop_MC 1 - time has passed: 64.48092889785767
#     loop_MC 2 - time has passed: 96.83448123931885
#     loop_MC 3 - time has passed: 129.74272894859314
#     loop_MC 4 - time has passed: 162.65215921401978
#     loop_MC 5 - time has passed: 194.48353552818298
#     loop_MC 6 - time has passed: 225.7665295600891
#     loop_MC 7 - time has passed: 257.12645173072815
#     loop_MC 8 - time has passed: 285.3900170326233
#     loop_MC 9 - time has passed: 317.3901870250702
#     loop_MC 10 - time has passed: 349.06341314315796
#     loop_MC 11 - time has passed: 380.49671244621277
#     loop_MC 12 - time has passed: 413.82361674308777
#     loop_MC 13 - time has passed: 444.9842929840088
#     loop_MC 14 - time has passed: 480.54389786720276
#     loop_MC 15 - time has passed: 511.71462869644165
#     loop_MC 16 - time has passed: 542.0357990264893
#     loop_MC 17 - time has passed: 573.3811514377594
#     loop_MC 18 - time has passed: 604.1872093677521
#     loop_MC 19 - time has passed: 636.688809633255
#     loop_MC 20 - time has passed: 668.7444083690643
#     loop_MC 21 - time has passed: 701.4826104640961
#     loop_MC 22 - time has passed: 734.0626521110535
#     loop_MC 23 - time has passed: 766.9368183612823
#     loop_MC 24 - time has passed: 803.6366107463837
#     loop_MC 25 - time has passed: 835.4194400310516
#     loop_MC 26 - time has passed: 868.1154854297638
#     loop_MC 27 - time has passed: 900.1466753482819
#     loop_MC 28 - time has passed: 931.0320093631744
#     loop_MC 29 - time has passed: 963.4683680534363
# loop_b 13 - time has passed: 15049.500485897064
#     loop_MC 0 - time has passed: 29.97890591621399
#     loop_MC 1 - time has passed: 62.82607650756836
#     loop_MC 2 - time has passed: 94.7322371006012
#     loop_MC 3 - time has passed: 124.20061469078064
#     loop_MC 4 - time has passed: 154.22035241127014
#     loop_MC 5 - time has passed: 186.34080171585083
#     loop_MC 6 - time has passed: 217.1814455986023
#     loop_MC 7 - time has passed: 248.51680541038513
#     loop_MC 8 - time has passed: 279.9969973564148
#     loop_MC 9 - time has passed: 311.3385865688324
#     loop_MC 10 - time has passed: 341.78931760787964
#     loop_MC 11 - time has passed: 374.68722128868103
#     loop_MC 12 - time has passed: 406.0973207950592
#     loop_MC 13 - time has passed: 437.69429636001587
#     loop_MC 14 - time has passed: 469.2668716907501
#     loop_MC 15 - time has passed: 506.3113968372345
#     loop_MC 16 - time has passed: 536.2905678749084
#     loop_MC 17 - time has passed: 568.4957091808319
#     loop_MC 18 - time has passed: 601.1689732074738
#     loop_MC 19 - time has passed: 632.7480943202972
#     loop_MC 20 - time has passed: 665.1489932537079
#     loop_MC 21 - time has passed: 695.6896126270294
#     loop_MC 22 - time has passed: 726.9308247566223
#     loop_MC 23 - time has passed: 762.2294118404388
#     loop_MC 24 - time has passed: 793.826940536499
#     loop_MC 25 - time has passed: 824.0535905361176
#     loop_MC 26 - time has passed: 855.7490086555481
#     loop_MC 27 - time has passed: 886.4016184806824
#     loop_MC 28 - time has passed: 917.7377152442932
#     loop_MC 29 - time has passed: 948.2747626304626
# loop_b 14 - time has passed: 15997.806494951248
#     loop_MC 0 - time has passed: 30.265416383743286
#     loop_MC 1 - time has passed: 61.13847351074219
#     loop_MC 2 - time has passed: 92.24747705459595
#     loop_MC 3 - time has passed: 122.72858905792236
#     loop_MC 4 - time has passed: 153.67487335205078
#     loop_MC 5 - time has passed: 183.65699982643127
#     loop_MC 6 - time has passed: 213.05813431739807
#     loop_MC 7 - time has passed: 245.2121183872223
#     loop_MC 8 - time has passed: 275.0301606655121
#     loop_MC 9 - time has passed: 305.1689019203186
#     loop_MC 10 - time has passed: 334.93050146102905
#     loop_MC 11 - time has passed: 364.2513144016266
#     loop_MC 12 - time has passed: 395.7057931423187
#     loop_MC 13 - time has passed: 425.7864468097687
#     loop_MC 14 - time has passed: 456.9507739543915
#     loop_MC 15 - time has passed: 487.3830304145813
#     loop_MC 16 - time has passed: 517.7070124149323
#     loop_MC 17 - time has passed: 549.5669310092926
#     loop_MC 18 - time has passed: 585.4741191864014
#     loop_MC 19 - time has passed: 622.5721714496613
#     loop_MC 20 - time has passed: 653.0537419319153
#     loop_MC 21 - time has passed: 683.6971416473389
#     loop_MC 22 - time has passed: 715.2005438804626
#     loop_MC 23 - time has passed: 747.1413576602936
#     loop_MC 24 - time has passed: 777.3414931297302
#     loop_MC 25 - time has passed: 814.1199383735657
#     loop_MC 26 - time has passed: 845.6202459335327
#     loop_MC 27 - time has passed: 874.4501395225525
#     loop_MC 28 - time has passed: 904.7573609352112
#     loop_MC 29 - time has passed: 941.6819849014282
# loop_b 15 - time has passed: 16939.535465478897
#     loop_MC 0 - time has passed: 29.925434112548828
#     loop_MC 1 - time has passed: 59.726497411727905
#     loop_MC 2 - time has passed: 90.00392556190491
#     loop_MC 3 - time has passed: 120.05705666542053
#     loop_MC 4 - time has passed: 149.44829654693604
#     loop_MC 5 - time has passed: 180.26769757270813
#     loop_MC 6 - time has passed: 209.8908519744873
#     loop_MC 7 - time has passed: 240.20497179031372
#     loop_MC 8 - time has passed: 271.68891191482544
#     loop_MC 9 - time has passed: 301.4792025089264
#     loop_MC 10 - time has passed: 337.0246729850769
#     loop_MC 11 - time has passed: 366.3620584011078
#     loop_MC 12 - time has passed: 402.6860771179199
#     loop_MC 13 - time has passed: 432.8205668926239
#     loop_MC 14 - time has passed: 463.89389657974243
#     loop_MC 15 - time has passed: 492.4967291355133
#     loop_MC 16 - time has passed: 524.68314909935
#     loop_MC 17 - time has passed: 556.1669516563416
#     loop_MC 18 - time has passed: 584.9821574687958
#     loop_MC 19 - time has passed: 614.6151716709137
#     loop_MC 20 - time has passed: 658.2047142982483
#     loop_MC 21 - time has passed: 692.9238245487213
#     loop_MC 22 - time has passed: 728.0384030342102
#     loop_MC 23 - time has passed: 765.309238910675
#     loop_MC 24 - time has passed: 809.5392711162567
#     loop_MC 25 - time has passed: 838.8232572078705
#     loop_MC 26 - time has passed: 869.6133372783661
#     loop_MC 27 - time has passed: 899.1653969287872
#     loop_MC 28 - time has passed: 929.145544052124
#     loop_MC 29 - time has passed: 959.6621716022491
# loop_b 16 - time has passed: 17899.22888159752
#     loop_MC 0 - time has passed: 31.223005771636963
#     loop_MC 1 - time has passed: 64.44508242607117
#     loop_MC 2 - time has passed: 98.75845956802368
#     loop_MC 3 - time has passed: 129.177796125412
#     loop_MC 4 - time has passed: 158.4394474029541
#     loop_MC 5 - time has passed: 187.0562183856964
#     loop_MC 6 - time has passed: 223.9581606388092
#     loop_MC 7 - time has passed: 261.08663725852966
#     loop_MC 8 - time has passed: 290.65981674194336
#     loop_MC 9 - time has passed: 320.67776823043823
#     loop_MC 10 - time has passed: 350.63727045059204
#     loop_MC 11 - time has passed: 378.80014276504517
#     loop_MC 12 - time has passed: 408.2207500934601
#     loop_MC 13 - time has passed: 437.3617923259735
#     loop_MC 14 - time has passed: 467.477676153183
#     loop_MC 15 - time has passed: 495.49117851257324
#     loop_MC 16 - time has passed: 525.4284632205963
#     loop_MC 17 - time has passed: 553.9417688846588
#     loop_MC 18 - time has passed: 583.8821814060211
#     loop_MC 19 - time has passed: 613.6876480579376
#     loop_MC 20 - time has passed: 643.0967061519623
#     loop_MC 21 - time has passed: 680.0477721691132
#     loop_MC 22 - time has passed: 710.3558003902435
#     loop_MC 23 - time has passed: 740.7867772579193
#     loop_MC 24 - time has passed: 770.5363826751709
#     loop_MC 25 - time has passed: 800.1635534763336
#     loop_MC 26 - time has passed: 829.332560300827
#     loop_MC 27 - time has passed: 857.8547015190125
#     loop_MC 28 - time has passed: 893.0835356712341
#     loop_MC 29 - time has passed: 922.6619546413422
# loop_b 17 - time has passed: 18821.922080278397
#     loop_MC 0 - time has passed: 29.84089183807373
#     loop_MC 1 - time has passed: 58.56304574012756
#     loop_MC 2 - time has passed: 87.57280898094177
#     loop_MC 3 - time has passed: 116.19665360450745
#     loop_MC 4 - time has passed: 145.0395085811615
#     loop_MC 5 - time has passed: 174.574449300766
#     loop_MC 6 - time has passed: 204.00014400482178
#     loop_MC 7 - time has passed: 232.2442433834076
#     loop_MC 8 - time has passed: 261.6683027744293
#     loop_MC 9 - time has passed: 289.97686314582825
#     loop_MC 10 - time has passed: 319.5288727283478
#     loop_MC 11 - time has passed: 349.8367269039154
#     loop_MC 12 - time has passed: 378.45776319503784
#     loop_MC 13 - time has passed: 406.87223529815674
#     loop_MC 14 - time has passed: 436.9689064025879
#     loop_MC 15 - time has passed: 466.3268461227417
#     loop_MC 16 - time has passed: 495.07994985580444
#     loop_MC 17 - time has passed: 522.9868636131287
#     loop_MC 18 - time has passed: 552.1241188049316
#     loop_MC 19 - time has passed: 582.1844582557678
#     loop_MC 20 - time has passed: 612.2241253852844
#     loop_MC 21 - time has passed: 642.9034674167633
#     loop_MC 22 - time has passed: 672.3881556987762
#     loop_MC 23 - time has passed: 702.1382825374603
#     loop_MC 24 - time has passed: 731.571489572525
#     loop_MC 25 - time has passed: 760.8303260803223
#     loop_MC 26 - time has passed: 789.3536190986633
#     loop_MC 27 - time has passed: 819.823502779007
#     loop_MC 28 - time has passed: 848.4978287220001
#     loop_MC 29 - time has passed: 877.193879365921
# loop_b 18 - time has passed: 19699.147201299667
#     loop_MC 0 - time has passed: 28.70937466621399
#     loop_MC 1 - time has passed: 57.51024055480957
#     loop_MC 2 - time has passed: 86.21811008453369
#     loop_MC 3 - time has passed: 123.67226934432983
#     loop_MC 4 - time has passed: 154.3852777481079
#     loop_MC 5 - time has passed: 184.58567714691162
#     loop_MC 6 - time has passed: 213.00864243507385
#     loop_MC 7 - time has passed: 242.49850511550903
#     loop_MC 8 - time has passed: 272.139283657074
#     loop_MC 9 - time has passed: 300.7426071166992
#     loop_MC 10 - time has passed: 329.2489757537842
#     loop_MC 11 - time has passed: 358.7549011707306
#     loop_MC 12 - time has passed: 394.9006941318512
#     loop_MC 13 - time has passed: 424.0017547607422
#     loop_MC 14 - time has passed: 452.3821783065796
#     loop_MC 15 - time has passed: 482.0557999610901
#     loop_MC 16 - time has passed: 512.3564467430115
#     loop_MC 17 - time has passed: 541.8580543994904
#     loop_MC 18 - time has passed: 579.036363363266
#     loop_MC 19 - time has passed: 607.5121133327484
#     loop_MC 20 - time has passed: 636.552844285965
#     loop_MC 21 - time has passed: 664.781316280365
#     loop_MC 22 - time has passed: 693.5592322349548
#     loop_MC 23 - time has passed: 728.7595400810242
#     loop_MC 24 - time has passed: 757.4562163352966
#     loop_MC 25 - time has passed: 785.1770515441895
#     loop_MC 26 - time has passed: 814.0940849781036
#     loop_MC 27 - time has passed: 843.5767593383789
#     loop_MC 28 - time has passed: 870.6359446048737
#     loop_MC 29 - time has passed: 899.9002869129181
# loop_b 19 - time has passed: 20599.094356060028
#     loop_MC 0 - time has passed: 28.844007968902588
#     loop_MC 1 - time has passed: 57.843594789505005
#     loop_MC 2 - time has passed: 86.70830821990967
#     loop_MC 3 - time has passed: 119.76228070259094
#     loop_MC 4 - time has passed: 148.88290739059448
#     loop_MC 5 - time has passed: 185.5609519481659
#     loop_MC 6 - time has passed: 213.1718225479126
#     loop_MC 7 - time has passed: 241.8548982143402
#     loop_MC 8 - time has passed: 270.28609919548035
#     loop_MC 9 - time has passed: 298.62211871147156
#     loop_MC 10 - time has passed: 326.554327249527
#     loop_MC 11 - time has passed: 355.81061720848083
#     loop_MC 12 - time has passed: 384.8141407966614
#     loop_MC 13 - time has passed: 413.2022054195404
#     loop_MC 14 - time has passed: 441.07221937179565
#     loop_MC 15 - time has passed: 468.9047076702118
#     loop_MC 16 - time has passed: 497.7722747325897
#     loop_MC 17 - time has passed: 525.4290482997894
#     loop_MC 18 - time has passed: 553.5818953514099
#     loop_MC 19 - time has passed: 581.6386556625366
#     loop_MC 20 - time has passed: 618.73095703125
#     loop_MC 21 - time has passed: 655.7624933719635
#     loop_MC 22 - time has passed: 685.1881167888641
#     loop_MC 23 - time has passed: 714.160279750824
#     loop_MC 24 - time has passed: 741.600888967514
#     loop_MC 25 - time has passed: 769.57395195961
#     loop_MC 26 - time has passed: 798.5586450099945
#     loop_MC 27 - time has passed: 833.4649875164032
#     loop_MC 28 - time has passed: 868.5743155479431
#     loop_MC 29 - time has passed: 900.9951758384705
# loop_b 20 - time has passed: 21500.117122411728
#     loop_MC 0 - time has passed: 28.68106198310852
#     loop_MC 1 - time has passed: 56.20228862762451
#     loop_MC 2 - time has passed: 85.32942795753479
#     loop_MC 3 - time has passed: 113.05158925056458
#     loop_MC 4 - time has passed: 142.31663584709167
#     loop_MC 5 - time has passed: 178.91703367233276
#     loop_MC 6 - time has passed: 207.1450593471527
#     loop_MC 7 - time has passed: 234.20848202705383
#     loop_MC 8 - time has passed: 262.51479053497314
#     loop_MC 9 - time has passed: 290.13459038734436
#     loop_MC 10 - time has passed: 317.3774163722992
#     loop_MC 11 - time has passed: 345.51017904281616
#     loop_MC 12 - time has passed: 373.59089851379395
#     loop_MC 13 - time has passed: 401.70170307159424
#     loop_MC 14 - time has passed: 430.3763029575348
#     loop_MC 15 - time has passed: 458.46631050109863
#     loop_MC 16 - time has passed: 487.0489993095398
#     loop_MC 17 - time has passed: 514.4188063144684
#     loop_MC 18 - time has passed: 541.7984809875488
#     loop_MC 19 - time has passed: 571.2334151268005
#     loop_MC 20 - time has passed: 599.3207507133484
#     loop_MC 21 - time has passed: 627.2143013477325
#     loop_MC 22 - time has passed: 654.8749349117279
#     loop_MC 23 - time has passed: 682.7068660259247
#     loop_MC 24 - time has passed: 710.5782115459442
#     loop_MC 25 - time has passed: 739.4205045700073
#     loop_MC 26 - time has passed: 767.6147027015686
#     loop_MC 27 - time has passed: 796.7579526901245
#     loop_MC 28 - time has passed: 825.1157310009003
#     loop_MC 29 - time has passed: 854.1197981834412
# loop_b 21 - time has passed: 22354.27348947525
#     loop_MC 0 - time has passed: 27.514198064804077
#     loop_MC 1 - time has passed: 55.02274179458618
#     loop_MC 2 - time has passed: 82.8260440826416
#     loop_MC 3 - time has passed: 110.61711430549622
#     loop_MC 4 - time has passed: 138.9599015712738
#     loop_MC 5 - time has passed: 167.42249965667725
#     loop_MC 6 - time has passed: 194.5446047782898
#     loop_MC 7 - time has passed: 222.31114673614502
#     loop_MC 8 - time has passed: 250.92623805999756
#     loop_MC 9 - time has passed: 278.2086741924286
#     loop_MC 10 - time has passed: 304.977219581604
#     loop_MC 11 - time has passed: 333.51660084724426
#     loop_MC 12 - time has passed: 362.72312235832214
#     loop_MC 13 - time has passed: 391.2754352092743
#     loop_MC 14 - time has passed: 428.89073038101196
#     loop_MC 15 - time has passed: 457.6041145324707
#     loop_MC 16 - time has passed: 485.3517851829529
#     loop_MC 17 - time has passed: 513.8719851970673
#     loop_MC 18 - time has passed: 541.4111983776093
#     loop_MC 19 - time has passed: 568.9239993095398
#     loop_MC 20 - time has passed: 598.2628862857819
#     loop_MC 21 - time has passed: 627.1508650779724
#     loop_MC 22 - time has passed: 655.2257633209229
#     loop_MC 23 - time has passed: 683.1143033504486
#     loop_MC 24 - time has passed: 711.9171912670135
#     loop_MC 25 - time has passed: 739.6154618263245
#     loop_MC 26 - time has passed: 767.8625407218933
#     loop_MC 27 - time has passed: 794.9072790145874
#     loop_MC 28 - time has passed: 823.1034488677979
#     loop_MC 29 - time has passed: 851.8260011672974
# loop_b 22 - time has passed: 23206.127079486847
#     loop_MC 0 - time has passed: 27.973930597305298
#     loop_MC 1 - time has passed: 55.84211874008179
#     loop_MC 2 - time has passed: 83.94102072715759
#     loop_MC 3 - time has passed: 111.70201849937439
#     loop_MC 4 - time has passed: 139.04532766342163
#     loop_MC 5 - time has passed: 167.0236735343933
#     loop_MC 6 - time has passed: 194.69016027450562
#     loop_MC 7 - time has passed: 222.38457989692688
#     loop_MC 8 - time has passed: 249.14204001426697
#     loop_MC 9 - time has passed: 277.6362910270691
#     loop_MC 10 - time has passed: 305.84049248695374
#     loop_MC 11 - time has passed: 333.3587305545807
#     loop_MC 12 - time has passed: 360.7798852920532
#     loop_MC 13 - time has passed: 387.8733100891113
#     loop_MC 14 - time has passed: 415.7265272140503
#     loop_MC 15 - time has passed: 444.0308315753937
#     loop_MC 16 - time has passed: 471.5908899307251
#     loop_MC 17 - time has passed: 499.54276871681213
#     loop_MC 18 - time has passed: 527.4928901195526
#     loop_MC 19 - time has passed: 555.8338711261749
#     loop_MC 20 - time has passed: 583.8227598667145
#     loop_MC 21 - time has passed: 611.8815619945526
#     loop_MC 22 - time has passed: 638.2482478618622
#     loop_MC 23 - time has passed: 666.6664984226227
#     loop_MC 24 - time has passed: 694.0771889686584
#     loop_MC 25 - time has passed: 722.4660949707031
#     loop_MC 26 - time has passed: 750.2524166107178
#     loop_MC 27 - time has passed: 779.3158564567566
#     loop_MC 28 - time has passed: 807.4327640533447
#     loop_MC 29 - time has passed: 834.8161778450012
# loop_b 23 - time has passed: 24040.97882771492
#     loop_MC 0 - time has passed: 26.388328552246094
#     loop_MC 1 - time has passed: 53.786651611328125
#     loop_MC 2 - time has passed: 81.80321168899536
#     loop_MC 3 - time has passed: 108.98951840400696
#     loop_MC 4 - time has passed: 137.47775435447693
#     loop_MC 5 - time has passed: 165.69917917251587
#     loop_MC 6 - time has passed: 192.7738721370697
#     loop_MC 7 - time has passed: 219.45381784439087
#     loop_MC 8 - time has passed: 255.96816039085388
#     loop_MC 9 - time has passed: 283.3265309333801
#     loop_MC 10 - time has passed: 311.4126081466675
#     loop_MC 11 - time has passed: 339.79478001594543
#     loop_MC 12 - time has passed: 368.21429204940796
#     loop_MC 13 - time has passed: 394.6617579460144
#     loop_MC 14 - time has passed: 422.62711572647095
#     loop_MC 15 - time has passed: 453.8916063308716
#     loop_MC 16 - time has passed: 481.4208791255951
#     loop_MC 17 - time has passed: 509.6321668624878
#     loop_MC 18 - time has passed: 536.1541020870209
#     loop_MC 19 - time has passed: 563.2657406330109
#     loop_MC 20 - time has passed: 590.8374056816101
#     loop_MC 21 - time has passed: 617.8516144752502
#     loop_MC 22 - time has passed: 645.2406997680664
#     loop_MC 23 - time has passed: 672.7234992980957
#     loop_MC 24 - time has passed: 700.4327085018158
#     loop_MC 25 - time has passed: 726.9859669208527
#     loop_MC 26 - time has passed: 755.1244757175446
#     loop_MC 27 - time has passed: 783.8645458221436
#     loop_MC 28 - time has passed: 811.0147113800049
#     loop_MC 29 - time has passed: 839.1977615356445
# loop_b 24 - time has passed: 24880.202185869217
#     loop_MC 0 - time has passed: 26.01766300201416
#     loop_MC 1 - time has passed: 53.819045066833496
#     loop_MC 2 - time has passed: 81.71710538864136
#     loop_MC 3 - time has passed: 109.60238146781921
#     loop_MC 4 - time has passed: 137.87325143814087
#     loop_MC 5 - time has passed: 165.58940744400024
#     loop_MC 6 - time has passed: 192.96180248260498
#     loop_MC 7 - time has passed: 220.39688777923584
#     loop_MC 8 - time has passed: 248.14647793769836
#     loop_MC 9 - time has passed: 275.9708173274994
#     loop_MC 10 - time has passed: 304.0978915691376
#     loop_MC 11 - time has passed: 331.4389214515686
#     loop_MC 12 - time has passed: 357.91514253616333
#     loop_MC 13 - time has passed: 384.5693917274475
#     loop_MC 14 - time has passed: 412.4222435951233
#     loop_MC 15 - time has passed: 440.9000151157379
#     loop_MC 16 - time has passed: 467.76032996177673
#     loop_MC 17 - time has passed: 495.59932255744934
#     loop_MC 18 - time has passed: 523.754184961319
#     loop_MC 19 - time has passed: 550.1315488815308
#     loop_MC 20 - time has passed: 578.4584205150604
#     loop_MC 21 - time has passed: 605.7213797569275
#     loop_MC 22 - time has passed: 631.7535891532898
#     loop_MC 23 - time has passed: 658.2489621639252
#     loop_MC 24 - time has passed: 684.4299721717834
#     loop_MC 25 - time has passed: 711.2147834300995
#     loop_MC 26 - time has passed: 739.5246787071228
#     loop_MC 27 - time has passed: 765.3250308036804
#     loop_MC 28 - time has passed: 791.9320838451385
#     loop_MC 29 - time has passed: 818.1605989933014
# loop_b 25 - time has passed: 25698.38073706627
#     loop_MC 0 - time has passed: 27.841827392578125
#     loop_MC 1 - time has passed: 54.53041386604309
#     loop_MC 2 - time has passed: 81.61920523643494
#     loop_MC 3 - time has passed: 108.58851075172424
#     loop_MC 4 - time has passed: 135.76368713378906
#     loop_MC 5 - time has passed: 163.0566074848175
#     loop_MC 6 - time has passed: 190.89749956130981
#     loop_MC 7 - time has passed: 218.01888918876648
#     loop_MC 8 - time has passed: 245.89203190803528
#     loop_MC 9 - time has passed: 272.81127095222473
#     loop_MC 10 - time has passed: 300.2569680213928
#     loop_MC 11 - time has passed: 326.4243850708008
#     loop_MC 12 - time has passed: 353.7306399345398
#     loop_MC 13 - time has passed: 382.59857153892517
#     loop_MC 14 - time has passed: 411.0930905342102
#     loop_MC 15 - time has passed: 439.1174941062927
#     loop_MC 16 - time has passed: 467.4494409561157
#     loop_MC 17 - time has passed: 494.03544783592224
#     loop_MC 18 - time has passed: 520.896600484848
#     loop_MC 19 - time has passed: 549.0008561611176
#     loop_MC 20 - time has passed: 575.8239145278931
#     loop_MC 21 - time has passed: 603.4345569610596
#     loop_MC 22 - time has passed: 630.7553939819336
#     loop_MC 23 - time has passed: 658.0567004680634
#     loop_MC 24 - time has passed: 685.3525416851044
#     loop_MC 25 - time has passed: 712.727151632309
#     loop_MC 26 - time has passed: 740.3802587985992
#     loop_MC 27 - time has passed: 767.6056270599365
#     loop_MC 28 - time has passed: 804.2828505039215
#     loop_MC 29 - time has passed: 830.5441360473633
# loop_b 26 - time has passed: 26528.956117391586
#     loop_MC 0 - time has passed: 26.386934757232666
#     loop_MC 1 - time has passed: 52.25734496116638
#     loop_MC 2 - time has passed: 79.88746690750122
#     loop_MC 3 - time has passed: 105.35575914382935
#     loop_MC 4 - time has passed: 132.6535460948944
#     loop_MC 5 - time has passed: 170.50646328926086
#     loop_MC 6 - time has passed: 198.35967469215393
#     loop_MC 7 - time has passed: 224.5381302833557
#     loop_MC 8 - time has passed: 251.7792568206787
#     loop_MC 9 - time has passed: 278.06194376945496
#     loop_MC 10 - time has passed: 304.6855311393738
#     loop_MC 11 - time has passed: 330.80338740348816
#     loop_MC 12 - time has passed: 358.24806094169617
#     loop_MC 13 - time has passed: 386.0208773612976
#     loop_MC 14 - time has passed: 412.03801560401917
#     loop_MC 15 - time has passed: 438.818589925766
#     loop_MC 16 - time has passed: 466.8723101615906
#     loop_MC 17 - time has passed: 494.00741934776306
#     loop_MC 18 - time has passed: 519.9062235355377
#     loop_MC 19 - time has passed: 545.8649554252625
#     loop_MC 20 - time has passed: 573.1835286617279
#     loop_MC 21 - time has passed: 599.3941373825073
#     loop_MC 22 - time has passed: 626.4206683635712
#     loop_MC 23 - time has passed: 654.6312079429626
#     loop_MC 24 - time has passed: 681.6115343570709
#     loop_MC 25 - time has passed: 707.5858011245728
#     loop_MC 26 - time has passed: 735.6326150894165
#     loop_MC 27 - time has passed: 762.808253288269
#     loop_MC 28 - time has passed: 789.6326816082001
#     loop_MC 29 - time has passed: 815.6657700538635
# loop_b 27 - time has passed: 27344.637510299683
#     loop_MC 0 - time has passed: 26.235716342926025
#     loop_MC 1 - time has passed: 51.86251711845398
#     loop_MC 2 - time has passed: 79.56747269630432
#     loop_MC 3 - time has passed: 107.50543642044067
#     loop_MC 4 - time has passed: 135.67360615730286
#     loop_MC 5 - time has passed: 161.57623648643494
#     loop_MC 6 - time has passed: 188.72053408622742
#     loop_MC 7 - time has passed: 215.16483306884766
#     loop_MC 8 - time has passed: 241.6730842590332
#     loop_MC 9 - time has passed: 268.4155955314636
#     loop_MC 10 - time has passed: 295.08541345596313
#     loop_MC 11 - time has passed: 321.4431903362274
#     loop_MC 12 - time has passed: 348.1094603538513
#     loop_MC 13 - time has passed: 375.5925860404968
#     loop_MC 14 - time has passed: 402.17238545417786
#     loop_MC 15 - time has passed: 430.2224564552307
#     loop_MC 16 - time has passed: 457.26245951652527
#     loop_MC 17 - time has passed: 483.8512783050537
#     loop_MC 18 - time has passed: 510.1153485774994
#     loop_MC 19 - time has passed: 536.9999957084656
#     loop_MC 20 - time has passed: 564.5671982765198
#     loop_MC 21 - time has passed: 591.4926972389221
#     loop_MC 22 - time has passed: 618.0987069606781
#     loop_MC 23 - time has passed: 645.1884603500366
#     loop_MC 24 - time has passed: 672.0660943984985
#     loop_MC 25 - time has passed: 698.3569195270538
#     loop_MC 26 - time has passed: 724.4351637363434
#     loop_MC 27 - time has passed: 751.4859347343445
#     loop_MC 28 - time has passed: 777.806024312973
#     loop_MC 29 - time has passed: 804.9626951217651
# loop_b 28 - time has passed: 28149.631450891495
#     loop_MC 0 - time has passed: 26.291691064834595
#     loop_MC 1 - time has passed: 52.87914490699768
#     loop_MC 2 - time has passed: 79.62643003463745
#     loop_MC 3 - time has passed: 105.19379925727844
#     loop_MC 4 - time has passed: 135.48007607460022
#     loop_MC 5 - time has passed: 161.81295442581177
#     loop_MC 6 - time has passed: 188.59731364250183
#     loop_MC 7 - time has passed: 215.00618314743042
#     loop_MC 8 - time has passed: 242.21146416664124
#     loop_MC 9 - time has passed: 269.13282442092896
#     loop_MC 10 - time has passed: 295.05643033981323
#     loop_MC 11 - time has passed: 321.3768844604492
#     loop_MC 12 - time has passed: 348.0805411338806
#     loop_MC 13 - time has passed: 375.64800095558167
#     loop_MC 14 - time has passed: 402.49900221824646
#     loop_MC 15 - time has passed: 428.839058637619
#     loop_MC 16 - time has passed: 455.6923508644104
#     loop_MC 17 - time has passed: 482.3713102340698
#     loop_MC 18 - time has passed: 509.3971893787384
#     loop_MC 19 - time has passed: 536.6397242546082
#     loop_MC 20 - time has passed: 563.6427302360535
#     loop_MC 21 - time has passed: 590.3820521831512
#     loop_MC 22 - time has passed: 617.1415705680847
#     loop_MC 23 - time has passed: 644.1606879234314
#     loop_MC 24 - time has passed: 669.939521074295
#     loop_MC 25 - time has passed: 695.5392396450043
#     loop_MC 26 - time has passed: 721.2235486507416
#     loop_MC 27 - time has passed: 749.1297557353973
#     loop_MC 28 - time has passed: 775.1429698467255
#     loop_MC 29 - time has passed: 800.9787788391113
# loop_b 29 - time has passed: 28950.625851392746
#     loop_MC 0 - time has passed: 25.53035616874695
#     loop_MC 1 - time has passed: 52.130929708480835
#     loop_MC 2 - time has passed: 78.2833845615387
#     loop_MC 3 - time has passed: 105.36840796470642
#     loop_MC 4 - time has passed: 131.67634057998657
#     loop_MC 5 - time has passed: 157.5092363357544
#     loop_MC 6 - time has passed: 183.17800092697144
#     loop_MC 7 - time has passed: 209.4017128944397
#     loop_MC 8 - time has passed: 235.96597957611084
#     loop_MC 9 - time has passed: 262.07434034347534
#     loop_MC 10 - time has passed: 288.65731954574585
#     loop_MC 11 - time has passed: 314.0078239440918
#     loop_MC 12 - time has passed: 339.5407860279083
#     loop_MC 13 - time has passed: 364.58277463912964
#     loop_MC 14 - time has passed: 390.6694564819336
#     loop_MC 15 - time has passed: 416.7715210914612
#     loop_MC 16 - time has passed: 441.5744433403015
#     loop_MC 17 - time has passed: 467.1775116920471
#     loop_MC 18 - time has passed: 493.55717945098877
#     loop_MC 19 - time has passed: 520.3625955581665
#     loop_MC 20 - time has passed: 547.4142622947693
#     loop_MC 21 - time has passed: 573.3912770748138
#     loop_MC 22 - time has passed: 600.4983060359955
#     loop_MC 23 - time has passed: 626.9554562568665
#     loop_MC 24 - time has passed: 652.8455741405487
#     loop_MC 25 - time has passed: 678.9290418624878
#     loop_MC 26 - time has passed: 705.1366329193115
#     loop_MC 27 - time has passed: 730.8135852813721
#     loop_MC 28 - time has passed: 757.7318141460419
#     loop_MC 29 - time has passed: 784.1249234676361
# loop_b 30 - time has passed: 29734.782019615173
#     loop_MC 0 - time has passed: 25.566907167434692
#     loop_MC 1 - time has passed: 51.10940408706665
#     loop_MC 2 - time has passed: 77.48616194725037
#     loop_MC 3 - time has passed: 103.17555975914001
#     loop_MC 4 - time has passed: 128.88696026802063
#     loop_MC 5 - time has passed: 155.62301325798035
#     loop_MC 6 - time has passed: 181.07349848747253
#     loop_MC 7 - time has passed: 207.8882532119751
#     loop_MC 8 - time has passed: 235.09700727462769
#     loop_MC 9 - time has passed: 259.9615693092346
#     loop_MC 10 - time has passed: 286.15229630470276
#     loop_MC 11 - time has passed: 312.6947965621948
#     loop_MC 12 - time has passed: 339.14751052856445
#     loop_MC 13 - time has passed: 364.7742643356323
#     loop_MC 14 - time has passed: 390.48642349243164
#     loop_MC 15 - time has passed: 417.1003067493439
#     loop_MC 16 - time has passed: 443.2403607368469
#     loop_MC 17 - time has passed: 469.68584156036377
#     loop_MC 18 - time has passed: 496.155535697937
#     loop_MC 19 - time has passed: 522.6593916416168
#     loop_MC 20 - time has passed: 548.4034049510956
#     loop_MC 21 - time has passed: 574.5235977172852
#     loop_MC 22 - time has passed: 600.1781237125397
#     loop_MC 23 - time has passed: 625.3147332668304
#     loop_MC 24 - time has passed: 652.5241923332214
#     loop_MC 25 - time has passed: 678.3619887828827
#     loop_MC 26 - time has passed: 706.234356880188
#     loop_MC 27 - time has passed: 732.4761199951172
#     loop_MC 28 - time has passed: 759.0892288684845
#     loop_MC 29 - time has passed: 785.5786311626434
# loop_b 31 - time has passed: 30520.399874687195
#     loop_MC 0 - time has passed: 25.962352752685547
#     loop_MC 1 - time has passed: 52.66436696052551
#     loop_MC 2 - time has passed: 79.76902770996094
#     loop_MC 3 - time has passed: 107.01812195777893
#     loop_MC 4 - time has passed: 132.13018131256104
#     loop_MC 5 - time has passed: 158.3665475845337
#     loop_MC 6 - time has passed: 184.4286015033722
#     loop_MC 7 - time has passed: 211.2358582019806
#     loop_MC 8 - time has passed: 237.30558443069458
#     loop_MC 9 - time has passed: 262.9701120853424
#     loop_MC 10 - time has passed: 288.5737977027893
#     loop_MC 11 - time has passed: 314.5939772129059
#     loop_MC 12 - time has passed: 340.84602642059326
#     loop_MC 13 - time has passed: 367.19959115982056
#     loop_MC 14 - time has passed: 393.24943470954895
#     loop_MC 15 - time has passed: 419.10723638534546
#     loop_MC 16 - time has passed: 445.1491847038269
#     loop_MC 17 - time has passed: 470.944620847702
#     loop_MC 18 - time has passed: 496.91728687286377
#     loop_MC 19 - time has passed: 523.0586957931519
#     loop_MC 20 - time has passed: 549.8739364147186
#     loop_MC 21 - time has passed: 575.5292553901672
#     loop_MC 22 - time has passed: 600.6300435066223
#     loop_MC 23 - time has passed: 625.7439134120941
#     loop_MC 24 - time has passed: 651.0294163227081
#     loop_MC 25 - time has passed: 676.0052661895752
#     loop_MC 26 - time has passed: 700.8032119274139
#     loop_MC 27 - time has passed: 726.4695270061493
#     loop_MC 28 - time has passed: 752.4216167926788
#     loop_MC 29 - time has passed: 777.9139001369476
# loop_b 32 - time has passed: 31298.337710618973
#     loop_MC 0 - time has passed: 26.56331515312195
#     loop_MC 1 - time has passed: 51.200358629226685
#     loop_MC 2 - time has passed: 77.45980930328369
#     loop_MC 3 - time has passed: 103.85947728157043
#     loop_MC 4 - time has passed: 129.75365567207336
#     loop_MC 5 - time has passed: 155.53419280052185
#     loop_MC 6 - time has passed: 183.2450909614563
#     loop_MC 7 - time has passed: 212.95414876937866
#     loop_MC 8 - time has passed: 239.88870000839233
#     loop_MC 9 - time has passed: 265.3018798828125
#     loop_MC 10 - time has passed: 291.4625790119171
#     loop_MC 11 - time has passed: 317.42488050460815
#     loop_MC 12 - time has passed: 344.4330689907074
#     loop_MC 13 - time has passed: 371.0630872249603
#     loop_MC 14 - time has passed: 397.4003884792328
#     loop_MC 15 - time has passed: 423.5603413581848
#     loop_MC 16 - time has passed: 448.84862184524536
#     loop_MC 17 - time has passed: 475.13848519325256
#     loop_MC 18 - time has passed: 499.972469329834
#     loop_MC 19 - time has passed: 526.3642206192017
#     loop_MC 20 - time has passed: 553.3284842967987
#     loop_MC 21 - time has passed: 578.7333228588104
#     loop_MC 22 - time has passed: 606.3036417961121
#     loop_MC 23 - time has passed: 632.6396973133087
#     loop_MC 24 - time has passed: 658.690153837204
#     loop_MC 25 - time has passed: 684.2920763492584
#     loop_MC 26 - time has passed: 710.5580780506134
#     loop_MC 27 - time has passed: 736.8250238895416
#     loop_MC 28 - time has passed: 763.2234599590302
#     loop_MC 29 - time has passed: 788.8914592266083
# loop_b 33 - time has passed: 32087.254103899002
#     loop_MC 0 - time has passed: 25.895188093185425
#     loop_MC 1 - time has passed: 51.94938802719116
#     loop_MC 2 - time has passed: 77.5800347328186
#     loop_MC 3 - time has passed: 103.72409796714783
#     loop_MC 4 - time has passed: 135.09997391700745
#     loop_MC 5 - time has passed: 167.32249069213867
#     loop_MC 6 - time has passed: 199.05655479431152
#     loop_MC 7 - time has passed: 226.2983808517456
#     loop_MC 8 - time has passed: 253.13955879211426
#     loop_MC 9 - time has passed: 279.0014865398407
#     loop_MC 10 - time has passed: 304.84448432922363
#     loop_MC 11 - time has passed: 329.9732027053833
#     loop_MC 12 - time has passed: 357.26329803466797
#     loop_MC 13 - time has passed: 383.07433676719666
#     loop_MC 14 - time has passed: 408.96324348449707
#     loop_MC 15 - time has passed: 434.68896532058716
#     loop_MC 16 - time has passed: 458.9076247215271
#     loop_MC 17 - time has passed: 485.661034822464
#     loop_MC 18 - time has passed: 512.7152864933014
#     loop_MC 19 - time has passed: 537.1580982208252
#     loop_MC 20 - time has passed: 563.0719392299652
#     loop_MC 21 - time has passed: 589.96053647995
#     loop_MC 22 - time has passed: 615.3183853626251
#     loop_MC 23 - time has passed: 640.8491702079773
#     loop_MC 24 - time has passed: 665.8886067867279
#     loop_MC 25 - time has passed: 691.8938028812408
#     loop_MC 26 - time has passed: 718.415050983429
#     loop_MC 27 - time has passed: 744.2039079666138
#     loop_MC 28 - time has passed: 769.4885241985321
#     loop_MC 29 - time has passed: 794.9382741451263
# loop_b 34 - time has passed: 32882.23783802986
#     loop_MC 0 - time has passed: 25.551629066467285
#     loop_MC 1 - time has passed: 52.678399324417114
#     loop_MC 2 - time has passed: 78.53731608390808
#     loop_MC 3 - time has passed: 104.06989049911499
#     loop_MC 4 - time has passed: 129.9960699081421
#     loop_MC 5 - time has passed: 154.89087963104248
#     loop_MC 6 - time has passed: 180.00799584388733
#     loop_MC 7 - time has passed: 206.84444785118103
#     loop_MC 8 - time has passed: 232.69191646575928
#     loop_MC 9 - time has passed: 259.220374584198
#     loop_MC 10 - time has passed: 285.3944809436798
#     loop_MC 11 - time has passed: 311.3885374069214
#     loop_MC 12 - time has passed: 336.5972924232483
#     loop_MC 13 - time has passed: 361.47028732299805
#     loop_MC 14 - time has passed: 387.3187675476074
#     loop_MC 15 - time has passed: 413.5752730369568
#     loop_MC 16 - time has passed: 439.9047486782074
#     loop_MC 17 - time has passed: 465.4226441383362
#     loop_MC 18 - time has passed: 491.8465242385864
#     loop_MC 19 - time has passed: 517.6835134029388
#     loop_MC 20 - time has passed: 544.0369458198547
#     loop_MC 21 - time has passed: 569.5421357154846
#     loop_MC 22 - time has passed: 596.1638195514679
#     loop_MC 23 - time has passed: 621.7032284736633
#     loop_MC 24 - time has passed: 647.2820007801056
#     loop_MC 25 - time has passed: 672.6732552051544
#     loop_MC 26 - time has passed: 698.9664618968964
#     loop_MC 27 - time has passed: 725.3359537124634
#     loop_MC 28 - time has passed: 750.9668686389923
#     loop_MC 29 - time has passed: 777.4325799942017
# loop_b 35 - time has passed: 33659.705986738205

# %%
print(i_beta_22_02)
# Out:
# [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 5.00000000e-05 2.25000000e-03 1.68833333e-02
#  6.82000000e-02 1.78100000e-01 2.71600000e-01 3.38583333e-01
#  3.70966667e-01 4.06700000e-01 4.60366667e-01 4.12966667e-01
#  4.42350000e-01 4.59683333e-01 5.49200000e-01 4.98400000e-01
#  5.29516667e-01 5.57150000e-01 5.86350000e-01 5.94616667e-01
#  6.04550000e-01 6.03666667e-01 6.14416667e-01 6.15866667e-01
#  6.47233333e-01 6.48483333e-01 6.50900000e-01 6.62200000e-01
#  6.62183333e-01 6.61550000e-01 6.63150000e-01 6.74216667e-01]

# %%
plt.plot(i_beta_22_02, color='blue')

# %%
scio.savemat('./i_beta_22_02.mat', {'i_beta_22_02': i_beta_22_02})
